# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
# di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import hail as hl
hl.init(tmp_dir='/net/scratch/people/plggosborcz', spark_conf={'spark.driver.memory': '10G', 'spark.executor.memory': '10G'})
# Out:
# Running on Apache Spark version 2.4.5
# SparkUI available at http://p0644.prometheus:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.62-84fa81b9ea3d
# LOGGING: writing to /net/archive/groups/plggneuromol/imdik-zekanowski-gts/analysis/burden-and-family/hail-20211027-1052-0.2.62-84fa81b9ea3d.log

# %%
from hail.plot import show
from pprint import pprint
from bokeh.layouts import gridplot
hl.plot.output_notebook()

import numpy as np
import pandas as pd
from functools import reduce
from itertools import chain
import statistics as stat
from collections import Counter
    
import bokeh.palettes

from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
mt = hl.read_matrix_table('/net/archive/groups/plggneuromol/imdik-zekanowski-gts/data/mts/oligogenic-model/to-delete-4.mt')

# %% [markdown]
# control loci: chr3 75704431 chr7 152407335 chr 1 33010120

# %%
mt.count()
# Out:
# (2394821, 185)

# %%
mt = hl.variant_qc(mt)

# %%
mt.checkpoint('/net/archive/groups/plggneuromol/imdik-zekanowski-gts/data/to-delete-5.mt')
# Out:
# 2021-10-27 10:56:39 Hail: INFO: wrote matrix table with 2394821 rows and 185 columns in 1324 partitions to /net/archive/groups/plggneuromol/imdik-zekanowski-gts/data/to-delete-5.mt
#     Total size: 2.39 GiB
#     * Rows/entries: 2.39 GiB
#     * Columns: 2.37 KiB
#     * Globals: 11.00 B
#     * Smallest partition: 0 rows (20.00 B)
#     * Largest partition:  8022 rows (9.17 MiB)

# %%
mt.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
#     'phenotypes': struct {
#         family: str,
#         sex: str,
#         kinship: str,
#         disease: str,
#         phenotype: str,
#         add_pheno: str,
#         heavy_tics: str
#     }
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'AC': array<int32>
#     'AF': array<float64>
#     'AN': int32
#     'a_index': int32
#     'was_split': bool
#     'gnomad_v3': struct {
#         v3_nfe: struct {
#             AC: int32,
#             AF: float64,
#             AN: int32,
#             homozygote_count: int32
#         },
#         intergenic_consequences: array<struct {
#             allele_num: int32,
#             consequence_terms: array<str>,
#             impact: str,
#             minimised: int32,
# ...

# %%
mt.filter_rows(mt.locus == hl.locus("chr1", 33010120, reference_genome='GRCh38')).variant_qc.p_value_hwe.show()
# Out:
# +---------------+------------+----------+
# | locus         | alleles    |   <expr> |
# +---------------+------------+----------+
# | locus<GRCh38> | array<str> |  float64 |
# +---------------+------------+----------+
# | chr1:33010120 | ["G","A"]  | 5.00e-01 |
# | chr1:33010120 | ["G","C"]  | 6.29e-24 |
# | chr1:33010120 | ["G","T"]  | 5.04e-01 |
# +---------------+------------+----------+

# %%
mt.filter_rows(mt.locus == hl.locus("chr3", 75704431, reference_genome='GRCh38')).variant_qc.p_value_hwe.show()
# Out:
# +---------------+-------------+----------+
# | locus         | alleles     |   <expr> |
# +---------------+-------------+----------+
# | locus<GRCh38> | array<str>  |  float64 |
# +---------------+-------------+----------+
# | chr3:75704431 | ["A","ATG"] | 1.52e-01 |
# | chr3:75704431 | ["A","G"]   | 4.77e-12 |
# +---------------+-------------+----------+

# %%
mt.filter_rows(mt.locus == hl.locus("chr7", 152407335, reference_genome='GRCh38')).variant_qc.p_value_hwe.show()
# Out:
# +----------------+------------+----------+
# | locus          | alleles    |   <expr> |
# +----------------+------------+----------+
# | locus<GRCh38>  | array<str> |  float64 |
# +----------------+------------+----------+
# | chr7:152407335 | ["C","T"]  | 3.15e-20 |
# +----------------+------------+----------+
